# %%
import json

# %% [markdown]
# ![1.%20Json%20serialization%20and%20deserialization.PNG](attachment:1.%20Json%20serialization%20and%20deserialization.PNG)

# %%
# Deserialize the JSON file
with open("../1_Json_data_Serialization/friends.json", "rt" ) as f:
    
    obj_load = json.load(f)
    print("load object datatype : ",type(obj_load))
    
    print(obj_load)
# Out:
# load object datatype :  <class 'dict'>
# {'Dan': [20, 'London', 123456], 'Maria': [25, 'Madrid', 789456]}

# %%
# Deserialize a str, bytes or bytearray instance containing a JSON document to a Python object.

json_doc = """{
    "Dan": [
        20,
        "London",
        123456
    ],
    "Maria": [
        25,
        "Madrid",
        789456
    ]
}"""

# %%
object2 = json.loads(json_doc)

print("load object datatype : ",type(object2))
print(object2)
# Out:
# load object datatype :  <class 'dict'>
# {'Dan': [20, 'London', 123456], 'Maria': [25, 'Madrid', 789456]}
